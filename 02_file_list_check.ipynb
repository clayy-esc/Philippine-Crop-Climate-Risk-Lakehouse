# %%
# List files in the volume to confirm visibility from compute
files = dbutils.fs.ls('/Volumes/crop_risk/bronze/raw_files/')

# Display the results
for file in files:
    print(f"Name: {file.name}, Path: {file.path}, Size: {file.size} bytes")

print(f"\nTotal files found: {len(files)}")

# %%
from pyspark.sql import types as T

schema_dictionary = T.StructType([
    T.StructField('file', T.StringType(), True),
    T.StructField('column_name', T.StringType(), True),
    T.StructField('data_type', T.StringType(), True),
    T.StructField('unit', T.StringType(), True),
    T.StructField('derived', T.StringType(), True),
    T.StructField('description', T.StringType(), True)
])

df_dictionary = spark.read.csv('/Volumes/crop_risk/bronze/raw_files/data_dictionary.csv',
                header=True,
                schema=schema_dictionary
                )

display(df_dictionary.limit(10))
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
spark.sql("SELECT * FROM read_files('/Volumes/crop_risk/bronze/raw_files/crop_trend_master.csv', format => 'csv', header => true)")
