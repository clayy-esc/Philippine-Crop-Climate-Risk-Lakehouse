# %%
# %sql

CREATE CATALOG IF NOT EXISTS crop_risk;

# %%
# %sql
USE CATALOG crop_risk;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS crop_risk.source_data;
CREATE SCHEMA IF NOT EXISTS crop_risk.bronze;
CREATE SCHEMA IF NOT EXISTS crop_risk.silver;
CREATE SCHEMA IF NOT EXISTS crop_risk.gold;

# %%
# %sql
SHOW DATABASES FROM crop_risk;
